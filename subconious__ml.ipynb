# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("subconscious_stability_dataset (2).csv")
df
# Out:
#       Micro_Expression_Rate  Eye_Movement_Variability  Heart_Rate_Variability  \
# 0                       NaN                      22.7                    81.9
# 1                       8.6                      24.8                    56.7
# 2                      16.2                      26.7                    48.0
# 3                      18.8                      37.5                     NaN
# 4                      18.5                      26.6                    62.0
# ...                     ...                       ...                     ...
# 8995                   15.0                      40.2                    70.8
# 8996                   17.6                      30.3                    44.6
# 8997                   10.9                      25.4                    58.8
# 8998                   15.6                      29.9                    71.5
# 8999                   12.2                      29.6                    44.4
#
# ...

# %%
df.head()
# Out:
#    Micro_Expression_Rate  Eye_Movement_Variability  Heart_Rate_Variability  \
# 0                    NaN                      22.7                    81.9
# 1                    8.6                      24.8                    56.7
# 2                   16.2                      26.7                    48.0
# 3                   18.8                      37.5                     NaN
# 4                   18.5                      26.6                    62.0
#
#    Breathing_Rate  Reaction_Time_ms  Error_Rate_Per_Task  \
# 0            14.7             308.5                  4.6
# 1            16.0             369.9                  3.6
# 2            19.2             270.5                  1.0
# 3            17.6             388.9                  3.2
# 4            18.2             259.4                  3.6
#
#    Sleep_Hours_Last_Night  Caffeine_Intake_mg Experience_Level Time_Of_Day  \
# 0                     NaN                93.7         Beginner     Evening
# ...

# %%
df.tail()
# Out:
#       Micro_Expression_Rate  Eye_Movement_Variability  Heart_Rate_Variability  \
# 8995                   15.0                      40.2                    70.8
# 8996                   17.6                      30.3                    44.6
# 8997                   10.9                      25.4                    58.8
# 8998                   15.6                      29.9                    71.5
# 8999                   12.2                      29.6                    44.4
#
#       Breathing_Rate  Reaction_Time_ms  Error_Rate_Per_Task  \
# 8995            19.8             327.5                  2.9
# 8996            14.4             321.7                  5.9
# 8997            12.0             295.2                  4.9
# 8998            11.0             283.3                  7.5
# 8999            15.4             289.7                  0.6
#
#       Sleep_Hours_Last_Night  Caffeine_Intake_mg Experience_Level Time_Of_Day  \
# ...

# %%
df.describe()
# Out:
#        Micro_Expression_Rate  Eye_Movement_Variability  \
# count            8280.000000               9000.000000
# mean               14.975725                 29.897244
# std                 3.963511                  6.068579
# min                -0.400000                  3.200000
# 25%                12.200000                 25.700000
# 50%                15.000000                 29.900000
# 75%                17.600000                 34.100000
# max                29.400000                 52.400000
#
#        Heart_Rate_Variability  Breathing_Rate  Reaction_Time_ms  \
# count             8280.000000     9000.000000        9000.00000
# mean                60.124143       16.003367         325.73920
# std                  9.880535        3.022321          65.18634
# min                 17.000000        5.700000         112.10000
# 25%                 53.500000       14.000000         286.80000
# 50%                 60.200000       16.000000         321.70000
# ...

# %%
df.shape
# Out:
# (9000, 12)

# %%
df.dtypes
# Out:
# Micro_Expression_Rate           float64
# Eye_Movement_Variability        float64
# Heart_Rate_Variability          float64
# Breathing_Rate                  float64
# Reaction_Time_ms                float64
# Error_Rate_Per_Task             float64
# Sleep_Hours_Last_Night          float64
# Caffeine_Intake_mg              float64
# Experience_Level                 object
# Time_Of_Day                      object
# Task_Type                        object
# Subconscious_Stability_Score    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Micro_Expression_Rate           720
# Eye_Movement_Variability          0
# Heart_Rate_Variability          720
# Breathing_Rate                    0
# Reaction_Time_ms                  0
# Error_Rate_Per_Task               0
# Sleep_Hours_Last_Night          720
# Caffeine_Intake_mg              720
# Experience_Level                  0
# Time_Of_Day                       0
# Task_Type                         0
# Subconscious_Stability_Score      0
# dtype: int64

# %%
df['Heart_Rate_Variability'].unique()
# Out:
# array([81.9, 56.7, 48. ,  nan, 62. , 65.6, 67.6, 79.6, 54. , 41.5, 51.1,
#        68.9, 55.1, 77.3, 45.7, 70.2, 69. , 65.3, 48.8, 61.3, 75.6, 56.5,
#        59.3, 69.8, 51.4, 62.1, 61.4, 56.8, 51.3, 29.3, 51.5, 67. , 46. ,
#        48.1, 72.2, 67.3, 63. , 52.4, 67.1, 69.1, 55.3, 56.1, 50.7, 67.7,
#        40.4, 38. , 40. , 38.6, 73.6, 67.9, 58.9, 74.7, 65. , 81.1, 53.4,
#        49.2, 60.2, 69.4, 61. , 56.4, 72.6, 52.3, 57.5, 64.7, 52.2, 55.2,
#        59.5, 48.4, 62.3, 57.7, 75.4, 60.8, 50.9, 68.2, 50. , 64.1, 59.7,
#        70.6, 54.1, 64.2, 71.7, 56.6, 41.7, 56. , 61.9, 70. , 54.8, 77.2,
#        47. , 61.6, 57.6, 73.5, 45.3, 64.3, 75.3, 51.7, 51.6, 40.1, 44.4,
#        49.4, 64.5, 66.6, 49.7, 53.8, 69.5, 70.4, 46.1, 43.3, 46.5, 76.5,
#        78.8, 49.3, 48.3, 68.8, 69.3, 66.8, 52. , 68.3, 62.4, 56.3, 63.9,
#        38.4, 68.1, 61.2, 61.1, 40.2, 58.4, 54.7, 51.9, 66.2, 77.4, 63.4,
#        52.8, 92.8, 66.1, 74.2, 64.4, 33.6, 53.1, 63.6, 33.7, 58.2, 62.2,
# ...

# %%
df['Heart_Rate_Variability']=df['Heart_Rate_Variability'].fillna(df['Heart_Rate_Variability'].mean())

# %%
df['Micro_Expression_Rate'].unique()
# Out:
# array([ nan,  8.6, 16.2, 18.8, 18.5,  5.5, 14. , 10.6, 15.6, 13.3, 17.4,
#        14.9,  7.4, 15. ,  9.4,  8.9, 15.2,  8.3, 13.2, 13. , 11.5, 12.2,
#        15.1, 12.1, 15.3, 13.5, 15.7, 18.4, 20.2, 16. , 13.4, 17.8, 12.3,
#        12.8, 12. , 17. , 14.6, 19.5, 11.1, 14.3, 13.6, 18. , 18.1, 11.8,
#        21.1, 20.7, 12.9, 20.5, 20.4, 11.7, 18.3, 14.8, 11. , 15.5, 17.2,
#        20.3, 21.8, 10.8, 13.7, 16.1, 12.7, 22.7, 20.9, 18.2,  9. , 10.5,
#         9.1, 10.3, 19.6, 14.2, 11.6, 15.4, 15.9, 16.4, 25.2, 12.4,  5.7,
#        19.2, 20.1,  9.5, 14.1, 16.7, 19. , 21.9, 17.3, 14.4, 14.7, 17.1,
#        16.6, 23.2, 24.4, 11.2, 11.9, 11.3, 10.4, 10. ,  9.9, 13.1, 16.8,
#        19.4,  8.1,  5.3,  9.2,  5.6, 21.4, 22.8, 21.3, 10.1,  9.6, 12.5,
#         8. , 17.7,  7.3,  7.8, 24.6, 19.3, 10.2, 25.8, 11.4, 14.5, 23.3,
#         8.8, 16.3,  6.1, 13.9, 15.8, 12.6, 17.6, 19.8, 20.6, 18.7, 22.9,
#        22.2, 18.6, 16.9, 17.9,  5.8, 19.1, 26.4,  9.3, 23.5, 13.8, 19.7,
# ...

# %%
df['Micro_Expression_Rate']=df['Micro_Expression_Rate'].fillna(df['Micro_Expression_Rate'].mean())

# %%
df['Sleep_Hours_Last_Night'].unique()
# Out:
# array([ nan,  6.4,  5. ,  9.4,  7.3,  6.5,  9.3,  7.4,  6.7,  5.8,  7.8,
#         8. ,  9.2, 10.4,  9.7,  5.9,  7.2,  8.3,  6.8,  8.4,  7.1,  8.1,
#         6. ,  5.6,  8.6,  7.7,  9.1,  8.7,  6.6,  8.5,  7.5, 11. ,  5.7,
#         6.3,  6.2,  8.2,  7.6, 10.1,  9.8,  8.8, 10. ,  3.2,  5.2,  5.4,
#         7. ,  5.3,  4.4,  6.1,  6.9, 10.6,  4.9,  3.8,  9. ,  5.1,  4.8,
#         4.6,  3.6,  7.9,  9.6,  3. ,  9.5,  8.9,  5.5,  9.9,  4.7, 10.8,
#        10.2,  4.5,  4.3,  4. , 11.3,  3.7,  4.1, 11.2,  4.2, 10.7, 10.5,
#         2.7, 10.3,  3.9,  3.4,  3.5,  1.9, 11.1,  3.3,  1.1,  2.2, 11.7,
#         2.8,  2.5,  3.1,  2.9,  0.3, 11.5, 11.8,  1.8, 10.9,  2.6,  2.3,
#        11.6, 11.4, 12.2])

# %%
df['Sleep_Hours_Last_Night']=df['Sleep_Hours_Last_Night'].fillna(df['Sleep_Hours_Last_Night'].mean())

# %%
df['Caffeine_Intake_mg'].unique()
# Out:
# array([ 93.7,  85.1, 180. , ...,  65.2, 261.3, -22.1], shape=(2513,))

# %%
df['Caffeine_Intake_mg'] = df['Caffeine_Intake_mg'].clip(lower=0)

# %%
df['Caffeine_Intake_mg']=df['Caffeine_Intake_mg'].fillna(df['Caffeine_Intake_mg'].mean())

# %%
df.isna().sum()
# Out:
# Micro_Expression_Rate           0
# Eye_Movement_Variability        0
# Heart_Rate_Variability          0
# Breathing_Rate                  0
# Reaction_Time_ms                0
# Error_Rate_Per_Task             0
# Sleep_Hours_Last_Night          0
# Caffeine_Intake_mg              0
# Experience_Level                0
# Time_Of_Day                     0
# Task_Type                       0
# Subconscious_Stability_Score    0
# dtype: int64

# %%
a=df['Experience_Level'].value_counts()
a
# Out:
# Experience_Level
# Beginner        3655
# Intermediate    3573
# Expert          1772
# Name: count, dtype: int64

# %%
plt.bar(a.index,a.values)
# Out:
# <BarContainer object of 3 artists>

# %%
b=df['Task_Type'].value_counts()
b
# Out:
# Task_Type
# Cognitive     3110
# Creative      3036
# Analytical    2854
# Name: count, dtype: int64

# %%
plt.bar(b.index,b.values)
# Out:
# <BarContainer object of 3 artists>

# %%
c=df['Time_Of_Day'].value_counts()
c
# Out:
# Time_Of_Day
# Afternoon    3597
# Morning      3113
# Evening      2290
# Name: count, dtype: int64

# %%
plt.bar(c.index,c.values)
# Out:
# <BarContainer object of 3 artists>

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
import numpy as np
q1=np.percentile(df['Reaction_Time_ms'],25,method='midpoint')
q3=np.percentile(df['Reaction_Time_ms'],75,method='midpoint')
IQR=q3-q1
print(q1)
print(q3)
print(IQR)
# Out:
# 286.8
# 356.8
# 70.0

# %%
upper=q3+1.5*IQR
upper_array=np.array(df['Reaction_Time_ms']>=upper)
print('Upper_bound:',upper)
print(upper_array.sum())
# Out:
# Upper_bound: 461.8
# 176

# %%
lower=q1-1.5*IQR
lower_array=np.array(df['Reaction_Time_ms']<=lower)
print('Lower_bound:',lower)
print(lower_array.sum())
# Out:
# Lower_bound: 181.8
# 25

# %%
df = df[(df['Reaction_Time_ms'] >= 181.8) & (df['Reaction_Time_ms'] <= 461.8)]

# %%
df.shape
# Out:
# (8799, 12)

# %%
q1=np.percentile(df['Caffeine_Intake_mg'],25,method='midpoint')
q3=np.percentile(df['Caffeine_Intake_mg'],75,method='midpoint')
IQR=q3-q1
print(q1)
print(q3)
print(IQR)
# Out:
# 85.2
# 156.1
# 70.89999999999999

# %%
upper=q3+1.5*IQR
upper_array=np.array(df['Caffeine_Intake_mg']>=upper)
print('Upper_bound:',upper)
print(upper_array.sum())
# Out:
# Upper_bound: 262.45
# 77

# %%
df = df[df['Caffeine_Intake_mg'] <= upper]

# %%
df.shape
# Out:
# (8722, 12)

# %%
q1=np.percentile(df['Micro_Expression_Rate'],25,method='midpoint')
q3=np.percentile(df['Micro_Expression_Rate'],75,method='midpoint')
IQR=q3-q1
print(q1)
print(q3)
print(IQR)
# Out:
# 12.5
# 17.4
# 4.899999999999999

# %%
upper=q3+1.5*IQR
upper_array=np.array(df['Micro_Expression_Rate']>=upper)
print('Upper_bound:',upper)
print(upper_array.sum())
# Out:
# Upper_bound: 24.749999999999996
# 51

# %%
lower=q1-1.5*IQR
lower_array=np.array(df['Micro_Expression_Rate']<=lower)
print('Lower_bound:',lower)
print(lower_array.sum())
# Out:
# Lower_bound: 5.150000000000002
# 53

# %%
df = df[(df['Micro_Expression_Rate'] >= 5.15) & (df['Micro_Expression_Rate'] <= 24.75)]

# %%
df.shape
# Out:
# (8618, 12)

# %%
q1=np.percentile(df['Heart_Rate_Variability'],25,method='midpoint')
q3=np.percentile(df['Heart_Rate_Variability'],75,method='midpoint')
IQR=q3-q1
print(q1)
print(q3)
print(IQR)
# Out:
# 54.1
# 66.1
# 11.999999999999993

# %%
upper=q3+1.5*IQR
upper_array=np.array(df['Heart_Rate_Variability']>=upper)
print('Upper_bound:',upper)
print(upper_array.sum())
# Out:
# Upper_bound: 84.09999999999998
# 55

# %%
lower=q1-1.5*IQR
lower_array=np.array(df['Heart_Rate_Variability']<=lower)
print('Lower_bound:',lower)
print(lower_array.sum())
# Out:
# Lower_bound: 36.10000000000001
# 63

# %%
lower = 36.10
upper = 84.10

df = df[(df['Heart_Rate_Variability'] >= lower) &
        (df['Heart_Rate_Variability'] <= upper)]

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
df.shape
# Out:
# (8502, 12)

# %%
df.corr(numeric_only=True)
# Out:
#                               Micro_Expression_Rate  Eye_Movement_Variability  \
# Micro_Expression_Rate                      1.000000                 -0.007704
# Eye_Movement_Variability                  -0.007704                  1.000000
# Heart_Rate_Variability                     0.017948                  0.006958
# Breathing_Rate                            -0.010437                  0.011622
# Reaction_Time_ms                          -0.000891                 -0.004150
# Error_Rate_Per_Task                        0.013078                  0.009964
# Sleep_Hours_Last_Night                     0.004565                 -0.002321
# Caffeine_Intake_mg                         0.008379                  0.014050
# Subconscious_Stability_Score              -0.173982                 -0.007119
#
#                               Heart_Rate_Variability  Breathing_Rate  \
# Micro_Expression_Rate                       0.017948       -0.010437
# ...

# %%
df.select_dtypes(include='number').corr()['Subconscious_Stability_Score'].sort_values(ascending=False)
# Out:
# Subconscious_Stability_Score    1.000000
# Heart_Rate_Variability          0.339542
# Sleep_Hours_Last_Night          0.113156
# Eye_Movement_Variability       -0.007119
# Breathing_Rate                 -0.009986
# Error_Rate_Per_Task            -0.075234
# Caffeine_Intake_mg             -0.138131
# Micro_Expression_Rate          -0.173982
# Reaction_Time_ms               -0.315312
# Name: Subconscious_Stability_Score, dtype: float64

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
df = df.drop(['Breathing_Rate', 'Eye_Movement_Variability'], axis=1)

# %%
df.shape
# Out:
# (8502, 10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# select numeric columns
num_cols = df.select_dtypes(include='number').columns

# remove target column from list
num_cols = num_cols.drop('Subconscious_Stability_Score')

# create regplots
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.regplot(x=df[col], y=df['Subconscious_Stability_Score'])
    plt.title(f'{col} vs Subconscious_Stability_Score')
    plt.show()

# %%
df= pd.get_dummies(
    df,
    columns=df.select_dtypes(include=['object']).columns,
    drop_first=True,
    dtype=int
)
df
# Out:
#       Micro_Expression_Rate  Heart_Rate_Variability  Reaction_Time_ms  \
# 0                 14.975725               81.900000             308.5
# 1                  8.600000               56.700000             369.9
# 2                 16.200000               48.000000             270.5
# 3                 18.800000               60.124143             388.9
# 4                 18.500000               62.000000             259.4
# ...                     ...                     ...               ...
# 8995              15.000000               70.800000             327.5
# 8996              17.600000               44.600000             321.7
# 8997              10.900000               58.800000             295.2
# 8998              15.600000               71.500000             283.3
# 8999              12.200000               44.400000             289.7
#
#       Error_Rate_Per_Task  Sleep_Hours_Last_Night  Caffeine_Intake_mg  \
# ...

# %%
df.shape
# Out:
# (8502, 13)

# %%
df.columns
# Out:
# Index(['Micro_Expression_Rate', 'Heart_Rate_Variability', 'Reaction_Time_ms',
#        'Error_Rate_Per_Task', 'Sleep_Hours_Last_Night', 'Caffeine_Intake_mg',
#        'Subconscious_Stability_Score', 'Experience_Level_Expert',
#        'Experience_Level_Intermediate', 'Time_Of_Day_Evening',
#        'Time_Of_Day_Morning', 'Task_Type_Cognitive', 'Task_Type_Creative'],
#       dtype='object')

# %%
x=df.drop('Subconscious_Stability_Score',axis=1)
y=df['Subconscious_Stability_Score']

# %%
x
# Out:
#       Micro_Expression_Rate  Heart_Rate_Variability  Reaction_Time_ms  \
# 0                 14.975725               81.900000             308.5
# 1                  8.600000               56.700000             369.9
# 2                 16.200000               48.000000             270.5
# 3                 18.800000               60.124143             388.9
# 4                 18.500000               62.000000             259.4
# ...                     ...                     ...               ...
# 8995              15.000000               70.800000             327.5
# 8996              17.600000               44.600000             321.7
# 8997              10.900000               58.800000             295.2
# 8998              15.600000               71.500000             283.3
# 8999              12.200000               44.400000             289.7
#
#       Error_Rate_Per_Task  Sleep_Hours_Last_Night  Caffeine_Intake_mg  \
# ...

# %%
y
# Out:
# 0       82.2
# 1       80.4
# 2       72.5
# 3       74.8
# 4       69.7
#         ...
# 8995    78.2
# 8996    63.9
# 8997    84.0
# 8998    84.8
# 8999    78.1
# Name: Subconscious_Stability_Score, Length: 8502, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=1)

# %%
x
# Out:
#       Micro_Expression_Rate  Heart_Rate_Variability  Reaction_Time_ms  \
# 0                 14.975725               81.900000             308.5
# 1                  8.600000               56.700000             369.9
# 2                 16.200000               48.000000             270.5
# 3                 18.800000               60.124143             388.9
# 4                 18.500000               62.000000             259.4
# ...                     ...                     ...               ...
# 8995              15.000000               70.800000             327.5
# 8996              17.600000               44.600000             321.7
# 8997              10.900000               58.800000             295.2
# 8998              15.600000               71.500000             283.3
# 8999              12.200000               44.400000             289.7
#
#       Error_Rate_Per_Task  Sleep_Hours_Last_Night  Caffeine_Intake_mg  \
# ...

# %%
y
# Out:
# 0       82.2
# 1       80.4
# 2       72.5
# 3       74.8
# 4       69.7
#         ...
# 8995    78.2
# 8996    63.9
# 8997    84.0
# 8998    84.8
# 8999    78.1
# Name: Subconscious_Stability_Score, Length: 8502, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_percentage_error, r2_score

ridge = Ridge()

param_grid = {
    'alpha': [0.001, 0.01, 0.1, 1, 10, 50, 100]
}

grid = GridSearchCV(ridge, param_grid, cv=5)

grid.fit(x_train, y_train)

best_model = grid.best_estimator_

y_pred = best_model.predict(x_test)

mape = mean_absolute_percentage_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Best Alpha:", grid.best_params_)
print("MAPE:", round(mape,4))
print("R2 Score:", round(r2,4))
# Out:
# Best Alpha: {'alpha': 10}
# MAPE: 0.0529
# R2 Score: 0.5819

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_percentage_error, r2_score

dt = DecisionTreeRegressor(random_state=42)

param_grid = {
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid = GridSearchCV(dt, param_grid, cv=5)

grid.fit(x_train, y_train)

best_model = grid.best_estimator_

y_pred = best_model.predict(x_test)

mape = mean_absolute_percentage_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Best Parameters:", grid.best_params_)
print("Decision Tree")
print("MAPE:", round(mape,4))
print("R2 Score:", round(r2,4))
# Out:
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Decision Tree
# MAPE: 0.0648
# R2 Score: 0.3922

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error, r2_score

model_rf = RandomForestRegressor(
    n_estimators=200,
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42
)

model_rf.fit(x_train, y_train)

y_pred_rf = model_rf.predict(x_test)

mape = mean_absolute_percentage_error(y_test, y_pred_rf)
r2 = r2_score(y_test, y_pred_rf)

print("Random Forest Regression (Tuned)")
print("MAPE:", round(mape,4))
print("R2 Score:", round(r2,4))
# Out:
# Random Forest Regression (Tuned)
# MAPE: 0.056
# R2 Score: 0.5362

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))

plt.scatter(y_test, y_pred)

plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values (Linear Regression)")

plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         color='red')

plt.show()

# %%
y_pred_test=best_model.predict([[14.975725,81.900000,308.5,4.6,7.002331,93.700000,0,0,1,0,1,0]])
y_pred_test
# Out:
# array([72.91904762])
